# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sqlalchemy import create_engine

DB_PROTOCOL = "postgresql+psycopg2://"
DB_URL = "sy91dhb:g5t49ao@178.156.142.230:5432/hd64m1ki"

engine = create_engine(DB_PROTOCOL + DB_URL)
engine
# Out:
# Engine(postgresql+psycopg2://sy91dhb:***@178.156.142.230:5432/hd64m1ki)

# %%
df = pd.read_sql("SELECT * FROM hacker_news.items WHERE type='story' LIMIT 100", engine)
df.head()
# Out:
#          id  dead   type             by                time  text parent  \
# 0   2177506  None  story  lotusleaf1987 2011-02-03 23:33:22  None   None
# 1   2177513  None  story  lotusleaf1987 2011-02-03 23:34:32  None   None
# 2   2177514  None  story          evo_9 2011-02-03 23:34:38  None   None
# 3   2177518  None  story       bmcmanus 2011-02-03 23:35:21         None
# 4   2177519  None  story         mjfern 2011-02-03 23:35:37  None   None
# ..      ...   ...    ...            ...                 ...   ...    ...
# 95  4076245  None  story       ridruejo 2012-06-06 22:10:03         None
# 96  4076248  None  story     jusben1369 2012-06-06 22:10:32         None
# 97  4076251  None  story  DanielRibeiro 2012-06-06 22:11:07  None   None
# 98  4076252  None  story         Zaheer 2012-06-06 22:11:07         None
# 99  4076253  None  story           ams1 2012-06-06 22:11:26  None   None
#
#                                                  kids  \
# 0                                                None
# 1                                                None
# 2                                           [2178074]
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                               None
# 97                                               None
# 98                                               None
# 99  [4076441, 4077029, 4076599, 4076538, 4077625, ...
#
#                                                   url  score  \
# 0   http://www.engadget.com/2011/02/03/cliq-xt-won...    2.0
# 1   http://www.engadget.com/2011/02/03/canadian-go...    1.0
# 2                     http://www.slate.com/id/2283221    3.0
# 3   http://www.businessinsider.com/ron-conway-mega...    4.0
# 4   http://www.bgr.com/2011/02/03/verizon-wireless...    1.0
# ..                                                ...    ...
# 95  http://blogs.technet.com/b/stbnewsbytes/archiv...    2.0
# 96  http://blog.spreedly.com/2012/6/6/pricing-subs...    1.0
# 97  http://www.softwarebyrob.com/2012/06/06/there-...    2.0
# 98  http://www.intertechtion.com/answers/6-6-2012....    1.0
# 99                  http://www.census.gov/developers/  173.0
#
#                                                 title  descendants
# 0   CLIQ XT won't get Android 2.1 upgrade, Motorol...          0.0
# 1   Canadian goverment vows to reverse CRTC decisi...          0.0
# 2   American anxiety: The three real reasons why w...          1.0
# 3               Ron Conway's Investment Megatrend Doc          0.0
# 4   Verizon Wireless to throttle data speeds of he...          0.0
# ..                                                ...          ...
# 95  New Azure IaaS offering to compete head on wit...          0.0
# 96               Pricing Subscription Plans Correctly          0.0
# 97  How a Seemingly Well-Planned Server Move Crash...          0.0
# 98  Interview Q: Correcting Code to print exactly ...          0.0
# 99                       The US Census now has an API         38.0
#
# [100 rows x 12 columns]
